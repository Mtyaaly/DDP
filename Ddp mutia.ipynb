# %%
#Satu. Buat daftar untuk menampilkan data pada kategori  kendaraan
#[Nama kendaraan, jenis kendaraan, merk kendaraan,  cc kendaraan]
kendaraan1= [ "avanza" , "mobil" , "toyota" , 1500 ]
print ( kendaraan1 )

Kendaraan1=kendaraan1+ [ "hitam" , 4 , 25_000_000 ]
Kendaraan1.hapus  ( "motor" )
print ( kendaraan1 )

#2.dari nomor 1 ditambahkan dari list yang sudah a da
#[warna kendaraan, jml ban kendaraan, harga kendar aan]
#dihapus jenis kendaraan nya
kendaraan1=kendaraan1+ [ "hitam" , 4 , 250_000 ]
print ( kendaraan1 )
# Out:
# ['Vario', 'motor', 'honda', 150]
# ['Vario', 'motor', 'honda', 150]
# ['Vario', 'motor', 'honda', 150, 'hitam', 4, 250000]

# %%
#3. Buat dengan match case
pesan =  """
menu:
1. menghitung luas persegi
2. menghitung lingkaran
3. menghitung luas segitiga
pilih menu:
"""
pilihan =  input ( pesan )

cocok dengan  pilihan : case "1" :     print  ( "anda memasukkan angka 1 untuk menghitung luas per segi" )     sisi =  int ( input ( "masukan sisi:" ))     luas = sisi * sisi print ( "luas persegi yang sisinya" ,  sisi , "adalah" ,  luas ) case "2" :     print  ( "kamu memilih 2 untuk menghitung luas lingkaran" )     jari_jari=  int ( input ( "masukan jari_jari:" ))     luas =  3 , 14  * jari_jari ** 2 print ( " luas lingkaran yang jari_jari" ,  jari_jari , "adalah" ,  luas ) case "3" :     print  ( "anda memasukan angka 3 untuk menghitung luas segi tiga" )     alas =  int ( input ( "masukan alas:" ))     tinggi =  int ( input ( "masukan tinggi:" ))     luas =  1 / 2  * alas * tinggi print ( "luas segitiga alasnya" ,  sayang , "dan tinggi" ,  tinggi , "adalah " ,  luas )

















#cetak keterangan dan hasil luas

  case  _ : print ( "masukan tidak valid" )
# Out:
# menu:
# 1. menghitung luas persegi
# 2. menghitung lingkaran
# 3. menghitung luas segitiga
# pilih menu:
# 3
# anda memasukan angka 3 untuk menghitung luas segitiga
# masukan alas:5
# masukan tinggi:2
# luas segitiga alasnya 5 dan tingginya 2 adalah  5.0
